# %%
import xarray
from src.test_problem.spatial_axis import SpatialAxis, spatial_axis_defn_dict
from src import nk_driver

# %%
defn_dict = spatial_axis_defn_dict(axisname="depth")
depth = SpatialAxis(defn_dict=defn_dict)
depth.__dict__
# Out:
# {'axisname': 'depth',
#  'units': 'm',
#  'edges': array([  0.        ,  10.        ,  20.01556422,  30.13357223,
#          40.5105243 ,  51.35498991,  62.91146049,  75.44560619,
#          89.23093679, 104.53686675, 121.61818433, 140.70592486,
#         161.99964809, 185.66111972, 211.80939693, 240.51731817,
#         271.80939693, 305.66111972, 341.99964809, 380.70592486,
#         421.61818433, 464.53686675, 509.23093679, 555.44560619,
#         602.91146049, 651.35498991, 700.5105243 , 750.13357223,
#         800.01556422, 850.        , 900.        ]),
#  'defn_dict_values': 'axisname=depth\nunits=m\nnlevs=30\nedge_start=0.0\nedge_end=900.0\ndelta_ratio_max=5.0',
#  '_nlevs': 30,
#  'mid': array([  5.        ,  15.00778211,  25.07456823,  35.32204827,
#          45.93275711,  57.1332252 ,  69.17853334,  82.33827149,
#          96.88390177, 113.07752554, 131.1620546 , 151.35278648,
#         173.8303839 , 198.73525832, 226.16335755, 256.16335755,
# ...
