# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from src.test_problem import setup_solver
from src import nk_driver
from src.share import args_replace, common_args
from src.utils import mkdir_exist_okay

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_restoring_surf_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--logging_reproducible", "--tracer_module_names", "phosphorus"]

# %%
# create override cfg file, append its fname to cfg_fnames, and add to args_base
override_cfg_fname = os.path.join(wdir, "override.cfg")
mkdir_exist_okay(wdir)
with open(override_cfg_fname, mode="w") as fptr:
    fptr.write("[modelinfo]\n")
    fptr.write("po4_s_restoring_opt=0\n")

parser, args_remaining = common_args(description="querying default args", model_name="test_problem", args_list=args_base)
args = args_replace(parser.parse_args(args_remaining))
cfg_fnames = ",".join([args.cfg_fnames, override_cfg_fname])

args_base.extend(["--cfg_fnames", cfg_fnames])

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# setup_solver.py:main:args.cfg_fnames="$repo_root/input/test_problem/newton_krylov.cfg,$repo_root/input/test_problem/model_params.cfg,$workdir/override.cfg"
# gen_invoker_script.py:gen_invoker_script:generating $workdir/nk_driver.sh
# setup_solver.py:main:grid_weight_fname="$workdir/depth_axis.nc"
# setup_solver.py:main:fp_iter=0
# setup_solver.py:main:init_iterate_fname="$workdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/52)
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     ...                              ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# share.py:get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# model_config.py:__init__:loading content from $repo_root/input/test_problem/tracer_module_defs.yaml
# model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# model_config.py:__init__:reading depth_delta from $workdir/depth_axis.nc for grid_weight
# solver_state.py:__init__:"Newton" iteration now 0
# tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=7.000151e-16
# tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=1.653679e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.563821e-01
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.374311e-02
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584781e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.076257e-02
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.957637e-03
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584395e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.111559e-02
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.595277e-03
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.290447e-04
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=-5.130297e-13
# tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.588369e-01
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=9.579582e-05
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.793648e+00
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=1.545151e-15
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=5.143240e-03
# solver_state.py:inc_iteration:"Newton" iteration now 1
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.793270e+00
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=6.749701e-16
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=1.290077e-03
# tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.793270e+00
# tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=6.749701e-16
# tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=1.290077e-03
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=8.909333e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=7.936326e-03
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.666796e-03
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.277299e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.579756e-03
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.369376e-04
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.255529e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.577205e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.070760e-04
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.684444e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=-3.534586e-14
# tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=8.405522e-03
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.290077e-03
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=1.354092e-05
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.787188e+00
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=-1.371895e-15
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=1.072669e-03
# solver_state.py:inc_iteration:"Newton" iteration now 2
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.787263e+00
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=2.906533e-15
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=2.639177e-04
# tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.787263e+00
# tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=2.906533e-15
# tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=2.639177e-04
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=1.855036e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.656009e-03
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=3.439220e-04
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.725679e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.254913e-04
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=2.795280e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.721236e-03
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.249806e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.192007e-05
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=3.433326e-06
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 02,mean[phosphorus]=-9.956811e-15
# tracer_module_state_base.py:log_vals:Newton increment 02,norm[phosphorus]=1.751783e-03
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=2.639177e-04
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=2.752301e-06
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,norm[phosphorus]=4.788523e+00
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,mean[phosphorus]=3.469447e-16
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,norm[phosphorus]=2.201248e-04
# solver_state.py:inc_iteration:"Newton" iteration now 3
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,norm[phosphorus]=4.788507e+00
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,mean[phosphorus]=-1.737287e-15
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,norm[phosphorus]=5.417332e-05
# tracer_module_state_base.py:log_vals:iteration=03,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=03,iterate,norm[phosphorus]=4.788507e+00
# tracer_module_state_base.py:log_vals:iteration=03,fcn,mean[phosphorus]=-1.737287e-15
# tracer_module_state_base.py:log_vals:iteration=03,fcn,norm[phosphorus]=5.417332e-05
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=3.806825e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=3.398467e-04
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=7.059295e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=3.541439e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-6.680945e-05
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=5.733735e-06
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=3.532332e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-6.670459e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=4.496944e-06
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=7.043932e-07
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 03,mean[phosphorus]=-6.329233e-16
# tracer_module_state_base.py:log_vals:Newton increment 03,norm[phosphorus]=3.595044e-04
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=5.417332e-05
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=5.645264e-07
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=03,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=03,pre-fp_iter,iterate,norm[phosphorus]=4.788249e+00
# tracer_module_state_base.py:log_vals:iteration=03,pre-fp_iter,fcn,mean[phosphorus]=-6.598094e-16
# tracer_module_state_base.py:log_vals:iteration=03,pre-fp_iter,fcn,norm[phosphorus]=4.521551e-05
# solver_state.py:inc_iteration:"Newton" iteration now 4
# tracer_module_state_base.py:log_vals:iteration=04,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=04,fp_iter=01,iterate,norm[phosphorus]=4.788252e+00
# tracer_module_state_base.py:log_vals:iteration=04,fp_iter=01,fcn,mean[phosphorus]=-1.115040e-15
# tracer_module_state_base.py:log_vals:iteration=04,fp_iter=01,fcn,norm[phosphorus]=1.112713e-05
# tracer_module_state_base.py:log_vals:iteration=04,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=04,iterate,norm[phosphorus]=4.788252e+00
# tracer_module_state_base.py:log_vals:iteration=04,fcn,mean[phosphorus]=-1.115040e-15
# tracer_module_state_base.py:log_vals:iteration=04,fcn,norm[phosphorus]=1.112713e-05
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=7.820741e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=6.981782e-05
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.450067e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=7.275474e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.372352e-05
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.178051e-06
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=7.256757e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.370198e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=9.238994e-07
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.447109e-07
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 04,mean[phosphorus]=-3.406826e-15
# tracer_module_state_base.py:log_vals:Newton increment 04,norm[phosphorus]=7.385561e-05
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.112713e-05
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=1.159942e-07
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=04,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=04,pre-fp_iter,iterate,norm[phosphorus]=4.788305e+00
# tracer_module_state_base.py:log_vals:iteration=04,pre-fp_iter,fcn,mean[phosphorus]=-7.165665e-16
# tracer_module_state_base.py:log_vals:iteration=04,pre-fp_iter,fcn,norm[phosphorus]=9.286427e-06
# solver_state.py:inc_iteration:"Newton" iteration now 5
# tracer_module_state_base.py:log_vals:iteration=05,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=05,fp_iter=01,iterate,norm[phosphorus]=4.788304e+00
# tracer_module_state_base.py:log_vals:iteration=05,fp_iter=01,fcn,mean[phosphorus]=1.067861e-15
# tracer_module_state_base.py:log_vals:iteration=05,fp_iter=01,fcn,norm[phosphorus]=2.285335e-06
# tracer_module_state_base.py:log_vals:iteration=05,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=05,iterate,norm[phosphorus]=4.788304e+00
# tracer_module_state_base.py:log_vals:iteration=05,fcn,mean[phosphorus]=1.067861e-15
# tracer_module_state_base.py:log_vals:iteration=05,fcn,norm[phosphorus]=2.285335e-06
# number of maximum Newton iterations exceeded
# False

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                      (depth: 30, depth_edges: 31, iteration: 6, nbnds: 2, region: 1)
# Coordinates:
#   * iteration                    (iteration) int32 0 1 2 3 4 5
#   * region                       (region) int32 0
#   * depth                        (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
#   * depth_edges                  (depth_edges) float64 0.0 10.0 ... 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/18)
#     iterate_mean_phosphorus      (iteration, region) float64 ...
#     iterate_norm_phosphorus      (iteration, region) float64 ...
#     fcn_mean_phosphorus          (iteration, region) float64 ...
#     fcn_norm_phosphorus          (iteration, region) float64 ...
#     increment_mean_phosphorus    (iteration, region) float64 ...
#     increment_norm_phosphorus    (iteration, region) float64 ...
#     ...                           ...
#     dop                          (iteration, region, depth) float64 ...
#     pop                          (iteration, region, depth) float64 ...
#     po4_s                        (iteration, region, depth) float64 ...
#     dop_s                        (iteration, region, depth) float64 ...
#     pop_s                        (iteration, region, depth) float64 ...
#     po4_uptake                   (iteration, region, depth) float64 ...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 05

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
