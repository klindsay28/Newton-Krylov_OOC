# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from src.test_problem import setup_solver
from src import nk_driver
from src.share import args_replace, common_args
from src.utils import mkdir_exist_okay

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_restoring_surf_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "phosphorus"]

# %%
# create override cfg file, append its fname to cfg_fnames, and add to args_base
override_cfg_fname = os.path.join(wdir, "override.cfg")
mkdir_exist_okay(wdir)
with open(override_cfg_fname, mode="w") as fptr:
    fptr.write("[modelinfo]\n")
    fptr.write("po4_s_restoring_opt=0\n")

parser, args_remaining = common_args(description="querying default args", model_name="test_problem", args_list=args_base)
args = args_replace(parser.parse_args(args_remaining))
cfg_fnames = ",".join([args.cfg_fnames, override_cfg_fname])

args_base.extend(["--cfg_fnames", cfg_fnames])

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-03-16 07:25:35,182:43878:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg,/Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/override.cfg"
# 2021-03-16 07:25:35,188:43878:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/nk_driver.sh
# 2021-03-16 07:25:35,191:43878:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/depth_axis.nc"
# 2021-03-16 07:25:35,221:43878:setup_solver.py:main:fp_iter=0
# 2021-03-16 07:25:59,461:43878:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:35: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/52)
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     ...                              ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:35: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:59: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# 2021-03-16 07:26:11,952:43878:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-03-16 07:26:11,952:43878:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-03-16 07:26:11,964:43878:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-03-16 07:26:11,965:43878:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-03-16 07:26:11,966:43878:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-03-16 07:26:11,967:43878:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/depth_axis.nc for grid_weight
# 2021-03-16 07:26:11,970:43878:solver_state.py:__init__:"Newton" iteration now 0
# 2021-03-16 07:26:33,987:43878:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:26:33,989:43878:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# 2021-03-16 07:26:33,990:43878:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=7.000151e-16
# 2021-03-16 07:26:33,992:43878:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# 2021-03-16 07:26:33,994:43878:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:26:56,026:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.563821e-01
# 2021-03-16 07:26:56,033:43878:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:27:18,555:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584781e-01
# 2021-03-16 07:27:18,557:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.076257e-02
# 2021-03-16 07:27:18,568:43878:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:27:37,488:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584395e-01
# 2021-03-16 07:27:37,489:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.111559e-02
# 2021-03-16 07:27:37,491:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.595277e-03
# 2021-03-16 07:27:37,499:43878:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:27:56,674:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584458e-01
# 2021-03-16 07:27:56,675:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.110973e-02
# 2021-03-16 07:27:56,676:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.604381e-03
# 2021-03-16 07:27:56,677:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-1.169727e-04
# 2021-03-16 07:27:56,691:43878:tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=-7.979199e-13
# 2021-03-16 07:27:56,692:43878:tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.588430e-01
# 2021-03-16 07:28:18,110:43878:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:28:18,112:43878:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-16 07:28:18,113:43878:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# 2021-03-16 07:28:18,114:43878:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=7.445066e-06
# 2021-03-16 07:28:18,116:43878:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:28:43,885:43878:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:28:43,887:43878:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.793635e+00
# 2021-03-16 07:28:43,888:43878:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=-9.904187e-16
# 2021-03-16 07:28:43,889:43878:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=5.092731e-03
# 2021-03-16 07:28:43,894:43878:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-03-16 07:29:05,581:43878:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:29:05,582:43878:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.793251e+00
# 2021-03-16 07:29:05,583:43878:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=1.185873e-15
# 2021-03-16 07:29:05,584:43878:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=1.279694e-03
# 2021-03-16 07:29:05,594:43878:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:29:05,595:43878:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.793251e+00
# 2021-03-16 07:29:05,596:43878:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=1.185873e-15
# 2021-03-16 07:29:05,597:43878:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=1.279694e-03
# 2021-03-16 07:29:05,598:43878:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:29:30,556:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=7.915638e-03
# 2021-03-16 07:29:30,561:43878:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:29:51,370:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.254001e-03
# 2021-03-16 07:29:51,373:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.569997e-03
# 2021-03-16 07:29:51,395:43878:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:30:09,317:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.232334e-03
# 2021-03-16 07:30:09,318:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.567477e-03
# 2021-03-16 07:30:09,319:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.064246e-04
# 2021-03-16 07:30:09,327:43878:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:30:27,687:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.235148e-03
# 2021-03-16 07:30:27,688:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.569775e-03
# 2021-03-16 07:30:27,689:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.100050e-04
# 2021-03-16 07:30:27,690:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-1.364983e-05
# 2021-03-16 07:30:27,705:43878:tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=-6.121622e-15
# 2021-03-16 07:30:27,706:43878:tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=8.384160e-03
# 2021-03-16 07:30:50,595:43878:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:30:50,596:43878:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-16 07:30:50,597:43878:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.279694e-03
# 2021-03-16 07:30:50,598:43878:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=9.818018e-07
# 2021-03-16 07:30:50,601:43878:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:31:11,190:43878:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:31:11,192:43878:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.787189e+00
# 2021-03-16 07:31:11,193:43878:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=1.666690e-15
# 2021-03-16 07:31:11,194:43878:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=1.066728e-03
# 2021-03-16 07:31:11,200:43878:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-03-16 07:31:33,123:43878:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:31:33,124:43878:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.787265e+00
# 2021-03-16 07:31:33,125:43878:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=-5.420977e-16
# 2021-03-16 07:31:33,126:43878:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=2.635951e-04
# 2021-03-16 07:31:33,136:43878:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:31:33,137:43878:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.787265e+00
# 2021-03-16 07:31:33,138:43878:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=-5.420977e-16
# 2021-03-16 07:31:33,139:43878:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=2.635951e-04
# 2021-03-16 07:31:33,141:43878:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:31:52,254:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.651533e-03
# 2021-03-16 07:31:52,260:43878:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:32:11,474:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.720985e-03
# 2021-03-16 07:32:11,476:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.249205e-04
# 2021-03-16 07:32:11,487:43878:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:32:28,710:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.716598e-03
# 2021-03-16 07:32:28,710:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.244122e-04
# 2021-03-16 07:32:28,711:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.178796e-05
# 2021-03-16 07:32:28,719:43878:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:32:46,777:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.717187e-03
# 2021-03-16 07:32:46,778:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.248840e-04
# 2021-03-16 07:32:46,779:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.252070e-05
# 2021-03-16 07:32:46,780:43878:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-2.777592e-06
# 2021-03-16 07:32:46,798:43878:tracer_module_state_base.py:log_vals:Newton increment 02,mean[phosphorus]=1.627920e-14
# 2021-03-16 07:32:46,799:43878:tracer_module_state_base.py:log_vals:Newton increment 02,norm[phosphorus]=1.747797e-03
# 2021-03-16 07:33:03,409:43878:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:33:03,411:43878:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-16 07:33:03,411:43878:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=2.635951e-04
# 2021-03-16 07:33:03,412:43878:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=2.025089e-07
# 2021-03-16 07:33:03,413:43878:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:33:23,288:43878:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:33:23,289:43878:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,norm[phosphorus]=4.788523e+00
# 2021-03-16 07:33:23,290:43878:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,mean[phosphorus]=4.615516e-16
# 2021-03-16 07:33:23,291:43878:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,norm[phosphorus]=2.199132e-04
# 2021-03-16 07:33:23,299:43878:solver_state.py:inc_iteration:"Newton" iteration now 3
# 2021-03-16 07:33:42,609:43878:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:33:42,610:43878:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,norm[phosphorus]=4.788508e+00
# 2021-03-16 07:33:42,612:43878:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,mean[phosphorus]=1.273311e-16
# 2021-03-16 07:33:42,613:43878:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,norm[phosphorus]=5.434524e-05
# 2021-03-16 07:33:42,625:43878:tracer_module_state_base.py:log_vals:iteration=03,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:33:42,626:43878:tracer_module_state_base.py:log_vals:iteration=03,iterate,norm[phosphorus]=4.788508e+00
# 2021-03-16 07:33:42,627:43878:tracer_module_state_base.py:log_vals:iteration=03,fcn,mean[phosphorus]=1.273311e-16
# 2021-03-16 07:33:42,628:43878:tracer_module_state_base.py:log_vals:iteration=03,fcn,norm[phosphorus]=5.434524e-05
# number of maximum Newton iterations exceeded
# False

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                    (depth: 30, depth_edges: 31, iteration: 4, nbnds: 2, region: 1)
# Coordinates:
#   * iteration                  (iteration) int32 0 1 2 3
#   * depth                      (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
#   * depth_edges                (depth_edges) float64 0.0 10.0 ... 850.0 900.0
# Dimensions without coordinates: nbnds, region
# Data variables: (12/16)
#     iterate_mean_phosphorus    (iteration, region) float64 ...
#     iterate_norm_phosphorus    (iteration, region) float64 ...
#     fcn_mean_phosphorus        (iteration, region) float64 ...
#     fcn_norm_phosphorus        (iteration, region) float64 ...
#     increment_mean_phosphorus  (iteration, region) float64 ...
#     increment_norm_phosphorus  (iteration, region) float64 ...
#     ...                         ...
#     dop                        (iteration, region, depth) float64 ...
#     pop                        (iteration, region, depth) float64 ...
#     po4_s                      (iteration, region, depth) float64 ...
#     dop_s                      (iteration, region, depth) float64 ...
#     pop_s                      (iteration, region, depth) float64 ...
#     po4_uptake                 (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:26:11: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 03

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
