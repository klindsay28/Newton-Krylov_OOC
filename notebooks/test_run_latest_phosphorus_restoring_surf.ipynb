# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from src.test_problem import setup_solver
from src import nk_driver
from src.share import args_replace, common_args
from src.utils import mkdir_exist_okay

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_restoring_surf_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "phosphorus"]

# %%
# create override cfg file, append its fname to cfg_fnames, and add to args_base
override_cfg_fname = os.path.join(wdir, "override.cfg")
mkdir_exist_okay(wdir)
with open(override_cfg_fname, mode="w") as fptr:
    fptr.write("[modelinfo]\n")
    fptr.write("po4_s_restoring_opt=0\n")

parser, args_remaining = common_args(description="querying default args", model_name="test_problem", args_list=args_base)
args = args_replace(parser.parse_args(args_remaining))
cfg_fnames = ",".join([args.cfg_fnames, override_cfg_fname])

args_base.extend(["--cfg_fnames", cfg_fnames])

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-03-15 11:47:00,696:28600:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg,/Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/override.cfg"
# 2021-03-15 11:47:00,700:28600:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/nk_driver.sh
# 2021-03-15 11:47:00,702:28600:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/depth_axis.nc"
# 2021-03-15 11:47:00,724:28600:setup_solver.py:main:fp_iter=0
# 2021-03-15 11:47:26,705:28600:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-15 11:47:00: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/52)
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     ...                              ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-03-15 11:47:00: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-15 11:47:26: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# 2021-03-15 11:47:39,765:28600:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-03-15 11:47:39,766:28600:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-03-15 11:47:39,780:28600:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-03-15 11:47:39,781:28600:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-03-15 11:47:39,782:28600:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-03-15 11:47:39,783:28600:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_phosphorus_restoring_surf_wdir/depth_axis.nc for grid_weight
# 2021-03-15 11:47:39,786:28600:solver_state.py:__init__:"Newton" iteration now 0
# 2021-03-15 11:48:03,761:28600:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:48:03,762:28600:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# 2021-03-15 11:48:03,764:28600:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=6.474855e-16
# 2021-03-15 11:48:03,765:28600:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# 2021-03-15 11:48:03,767:28600:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-15 11:48:26,142:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.563887e-01
# 2021-03-15 11:48:26,148:28600:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-15 11:48:47,849:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584800e-01
# 2021-03-15 11:48:47,851:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.074929e-02
# 2021-03-15 11:48:47,858:28600:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-15 11:49:07,459:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584407e-01
# 2021-03-15 11:49:07,460:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.110008e-02
# 2021-03-15 11:49:07,462:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.587455e-03
# 2021-03-15 11:49:07,471:28600:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-15 11:49:27,085:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.584470e-01
# 2021-03-15 11:49:27,086:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.109427e-02
# 2021-03-15 11:49:27,088:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.596356e-03
# 2021-03-15 11:49:27,089:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-1.164475e-04
# 2021-03-15 11:49:27,103:28600:tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=-1.680919e-12
# 2021-03-15 11:49:27,104:28600:tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.588430e-01
# 2021-03-15 11:49:48,326:28600:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-15 11:49:48,328:28600:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-15 11:49:48,329:28600:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# 2021-03-15 11:49:48,331:28600:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=7.373316e-06
# 2021-03-15 11:49:48,332:28600:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-15 11:50:09,078:28600:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:50:09,079:28600:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.793635e+00
# 2021-03-15 11:50:09,081:28600:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=8.217710e-16
# 2021-03-15 11:50:09,082:28600:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=5.092707e-03
# 2021-03-15 11:50:09,087:28600:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-03-15 11:50:30,166:28600:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:50:30,167:28600:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.793251e+00
# 2021-03-15 11:50:30,169:28600:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=2.942796e-15
# 2021-03-15 11:50:30,170:28600:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=1.279709e-03
# 2021-03-15 11:50:30,182:28600:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:50:30,183:28600:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.793251e+00
# 2021-03-15 11:50:30,184:28600:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=2.942796e-15
# 2021-03-15 11:50:30,186:28600:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=1.279709e-03
# 2021-03-15 11:50:30,187:28600:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-15 11:50:50,438:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=7.916517e-03
# 2021-03-15 11:50:50,445:28600:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-15 11:51:10,471:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.254213e-03
# 2021-03-15 11:51:10,472:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.569467e-03
# 2021-03-15 11:51:10,480:28600:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-15 11:51:29,560:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.232538e-03
# 2021-03-15 11:51:29,561:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.566984e-03
# 2021-03-15 11:51:29,562:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.064353e-04
# 2021-03-15 11:51:29,571:28600:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-15 11:51:49,562:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=8.235349e-03
# 2021-03-15 11:51:49,564:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.569286e-03
# 2021-03-15 11:51:49,565:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.100169e-04
# 2021-03-15 11:51:49,567:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-1.365783e-05
# 2021-03-15 11:51:49,583:28600:tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=-3.664994e-14
# 2021-03-15 11:51:49,584:28600:tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=8.384266e-03
# 2021-03-15 11:52:11,461:28600:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-15 11:52:11,462:28600:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-15 11:52:11,464:28600:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.279709e-03
# 2021-03-15 11:52:11,465:28600:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=9.804573e-07
# 2021-03-15 11:52:11,466:28600:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-15 11:52:32,427:28600:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:52:32,429:28600:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.787189e+00
# 2021-03-15 11:52:32,430:28600:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=2.602871e-15
# 2021-03-15 11:52:32,431:28600:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=1.066741e-03
# 2021-03-15 11:52:32,436:28600:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-03-15 11:52:53,461:28600:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:52:53,462:28600:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.787265e+00
# 2021-03-15 11:52:53,464:28600:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=3.364212e-16
# 2021-03-15 11:52:53,465:28600:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=2.635976e-04
# 2021-03-15 11:52:53,476:28600:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:52:53,478:28600:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.787265e+00
# 2021-03-15 11:52:53,479:28600:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=3.364212e-16
# 2021-03-15 11:52:53,480:28600:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=2.635976e-04
# 2021-03-15 11:52:53,482:28600:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-15 11:53:12,858:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.651760e-03
# 2021-03-15 11:53:12,865:28600:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-15 11:53:32,029:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.721074e-03
# 2021-03-15 11:53:32,029:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.248102e-04
# 2021-03-15 11:53:32,037:28600:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-15 11:53:49,274:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.716685e-03
# 2021-03-15 11:53:49,274:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.243094e-04
# 2021-03-15 11:53:49,275:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.179246e-05
# 2021-03-15 11:53:49,285:28600:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-15 11:54:06,179:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.717273e-03
# 2021-03-15 11:54:06,180:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-3.247818e-04
# 2021-03-15 11:54:06,181:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.252551e-05
# 2021-03-15 11:54:06,183:28600:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-2.779490e-06
# 2021-03-15 11:54:06,198:28600:tracer_module_state_base.py:log_vals:Newton increment 02,mean[phosphorus]=-2.822527e-14
# 2021-03-15 11:54:06,199:28600:tracer_module_state_base.py:log_vals:Newton increment 02,norm[phosphorus]=1.747863e-03
# 2021-03-15 11:54:24,731:28600:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-15 11:54:24,732:28600:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-15 11:54:24,733:28600:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=2.635976e-04
# 2021-03-15 11:54:24,734:28600:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=2.025384e-07
# 2021-03-15 11:54:24,735:28600:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-15 11:54:43,360:28600:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:54:43,361:28600:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,norm[phosphorus]=4.788523e+00
# 2021-03-15 11:54:43,362:28600:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,mean[phosphorus]=-6.401875e-16
# 2021-03-15 11:54:43,363:28600:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,norm[phosphorus]=2.199171e-04
# 2021-03-15 11:54:43,369:28600:solver_state.py:inc_iteration:"Newton" iteration now 3
# 2021-03-15 11:55:01,640:28600:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:55:01,641:28600:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,norm[phosphorus]=4.788508e+00
# 2021-03-15 11:55:01,642:28600:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,mean[phosphorus]=1.347756e-15
# 2021-03-15 11:55:01,643:28600:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,norm[phosphorus]=5.434627e-05
# 2021-03-15 11:55:01,655:28600:tracer_module_state_base.py:log_vals:iteration=03,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-15 11:55:01,656:28600:tracer_module_state_base.py:log_vals:iteration=03,iterate,norm[phosphorus]=4.788508e+00
# 2021-03-15 11:55:01,657:28600:tracer_module_state_base.py:log_vals:iteration=03,fcn,mean[phosphorus]=1.347756e-15
# 2021-03-15 11:55:01,657:28600:tracer_module_state_base.py:log_vals:iteration=03,fcn,norm[phosphorus]=5.434627e-05
# number of maximum Newton iterations exceeded
# False

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                    (depth: 30, depth_edges: 31, iteration: 4, nbnds: 2, region: 1)
# Coordinates:
#   * iteration                  (iteration) int32 0 1 2 3
#   * depth                      (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
#   * depth_edges                (depth_edges) float64 0.0 10.0 ... 850.0 900.0
# Dimensions without coordinates: nbnds, region
# Data variables: (12/16)
#     iterate_mean_phosphorus    (iteration, region) float64 ...
#     iterate_norm_phosphorus    (iteration, region) float64 ...
#     fcn_mean_phosphorus        (iteration, region) float64 ...
#     fcn_norm_phosphorus        (iteration, region) float64 ...
#     increment_mean_phosphorus  (iteration, region) float64 ...
#     increment_norm_phosphorus  (iteration, region) float64 ...
#     ...                         ...
#     dop                        (iteration, region, depth) float64 ...
#     pop                        (iteration, region, depth) float64 ...
#     po4_s                      (iteration, region, depth) float64 ...
#     dop_s                      (iteration, region, depth) float64 ...
#     pop_s                      (iteration, region, depth) float64 ...
#     po4_uptake                 (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-03-15 11:47:39: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 03

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
