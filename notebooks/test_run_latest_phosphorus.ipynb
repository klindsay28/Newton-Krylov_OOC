# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from src.test_problem import setup_solver
from src import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "phosphorus"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-03-16 07:25:41,926:43887:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg"
# 2021-03-16 07:25:41,932:43887:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_phosphorus_wdir/nk_driver.sh
# 2021-03-16 07:25:41,936:43887:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_phosphorus_wdir/depth_axis.nc"
# 2021-03-16 07:25:41,959:43887:setup_solver.py:main:fp_iter=0
# 2021-03-16 07:26:08,300:43887:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_phosphorus_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:41: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/52)
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     ...                              ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:41: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:26:08: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# 2021-03-16 07:26:20,421:43887:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-03-16 07:26:20,422:43887:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-03-16 07:26:20,437:43887:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-03-16 07:26:20,438:43887:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-03-16 07:26:20,440:43887:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-03-16 07:26:20,441:43887:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_phosphorus_wdir/depth_axis.nc for grid_weight
# 2021-03-16 07:26:20,444:43887:solver_state.py:__init__:"Newton" iteration now 0
# 2021-03-16 07:26:45,153:43887:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:26:45,155:43887:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# 2021-03-16 07:26:45,157:43887:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=8.222589e-16
# 2021-03-16 07:26:45,159:43887:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# 2021-03-16 07:26:45,164:43887:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:27:08,463:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.549019e-01
# 2021-03-16 07:27:08,469:43887:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:27:31,436:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.564621e-01
# 2021-03-16 07:27:31,437:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-9.100911e-03
# 2021-03-16 07:27:31,444:43887:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:27:52,181:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.564571e-01
# 2021-03-16 07:27:52,182:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-9.290782e-03
# 2021-03-16 07:27:52,183:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.046636e-03
# 2021-03-16 07:27:52,193:43887:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:28:13,504:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.564640e-01
# 2021-03-16 07:28:13,505:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-9.284034e-03
# 2021-03-16 07:28:13,506:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.067693e-03
# 2021-03-16 07:28:13,507:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-9.836075e-05
# 2021-03-16 07:28:13,522:43887:tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=-1.788369e-12
# 2021-03-16 07:28:13,523:43887:tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.567429e-01
# 2021-03-16 07:28:40,569:43887:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:28:40,572:43887:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-16 07:28:40,574:43887:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# 2021-03-16 07:28:40,576:43887:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=4.207233e-06
# 2021-03-16 07:28:40,578:43887:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:29:04,318:43887:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:29:04,319:43887:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.788402e+00
# 2021-03-16 07:29:04,320:43887:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=6.101263e-17
# 2021-03-16 07:29:04,322:43887:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=1.052141e-04
# 2021-03-16 07:29:04,326:43887:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-03-16 07:29:32,363:43887:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:29:32,365:43887:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.788397e+00
# 2021-03-16 07:29:32,365:43887:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=9.949808e-16
# 2021-03-16 07:29:32,366:43887:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=2.173466e-05
# 2021-03-16 07:29:32,377:43887:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:29:32,378:43887:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.788397e+00
# 2021-03-16 07:29:32,379:43887:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=9.949808e-16
# 2021-03-16 07:29:32,380:43887:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=2.173466e-05
# 2021-03-16 07:29:32,382:43887:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:29:54,495:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.585819e-04
# 2021-03-16 07:29:54,501:43887:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:30:13,955:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.610631e-04
# 2021-03-16 07:30:13,956:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.642349e-05
# 2021-03-16 07:30:13,963:43887:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:30:34,299:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.609081e-04
# 2021-03-16 07:30:34,300:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.645072e-05
# 2021-03-16 07:30:34,301:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=9.699754e-07
# 2021-03-16 07:30:34,310:43887:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:30:56,070:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.609350e-04
# 2021-03-16 07:30:56,072:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-1.646321e-05
# 2021-03-16 07:30:56,073:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.005122e-06
# 2021-03-16 07:30:56,074:43887:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-1.246604e-07
# 2021-03-16 07:30:56,091:43887:tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=2.478134e-15
# 2021-03-16 07:30:56,092:43887:tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=1.617781e-04
# 2021-03-16 07:31:17,771:43887:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:31:17,773:43887:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-16 07:31:17,774:43887:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=2.173466e-05
# 2021-03-16 07:31:17,775:43887:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=4.903381e-09
# 2021-03-16 07:31:17,778:43887:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:31:40,887:43887:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:31:40,889:43887:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-16 07:31:40,890:43887:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=7.939525e-16
# 2021-03-16 07:31:40,891:43887:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=4.760836e-09
# 2021-03-16 07:31:40,897:43887:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-03-16 07:32:03,225:43887:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:32:03,227:43887:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-16 07:32:03,229:43887:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=-3.108452e-16
# 2021-03-16 07:32:03,231:43887:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=6.576386e-10
# 2021-03-16 07:32:03,248:43887:nk_driver.py:main:convergence criterion satisfied
# 2021-03-16 07:32:03,250:43887:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-16 07:32:03,252:43887:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-16 07:32:03,254:43887:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=-3.108452e-16
# 2021-03-16 07:32:03,256:43887:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=6.576386e-10

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                    (depth: 30, depth_edges: 31, iteration: 3, nbnds: 2, region: 1)
# Coordinates:
#   * iteration                  (iteration) int32 0 1 2
#   * depth                      (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
#   * depth_edges                (depth_edges) float64 0.0 10.0 ... 850.0 900.0
# Dimensions without coordinates: nbnds, region
# Data variables: (12/16)
#     iterate_mean_phosphorus    (iteration, region) float64 ...
#     iterate_norm_phosphorus    (iteration, region) float64 ...
#     fcn_mean_phosphorus        (iteration, region) float64 ...
#     fcn_norm_phosphorus        (iteration, region) float64 ...
#     increment_mean_phosphorus  (iteration, region) float64 ...
#     increment_norm_phosphorus  (iteration, region) float64 ...
#     ...                         ...
#     dop                        (iteration, region, depth) float64 ...
#     pop                        (iteration, region, depth) float64 ...
#     po4_s                      (iteration, region, depth) float64 ...
#     dop_s                      (iteration, region, depth) float64 ...
#     pop_s                      (iteration, region, depth) float64 ...
#     po4_uptake                 (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:26:20: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 02

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
