# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from src.test_problem import setup_solver
from src import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "phosphorus"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-03-22 09:03:47,297:76100:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg"
# 2021-03-22 09:03:47,303:76100:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_phosphorus_wdir/nk_driver.sh
# 2021-03-22 09:03:47,308:76100:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_phosphorus_wdir/depth_axis.nc"
# 2021-03-22 09:03:47,333:76100:setup_solver.py:main:fp_iter=0
# 2021-03-22 09:04:12,724:76100:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_phosphorus_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-22 09:03:47: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/52)
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     ...                              ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-03-22 09:03:47: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-03-22 09:04:12: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# 2021-03-22 09:04:25,566:76100:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-03-22 09:04:25,568:76100:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-03-22 09:04:25,584:76100:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-03-22 09:04:25,586:76100:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-03-22 09:04:25,587:76100:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-03-22 09:04:25,589:76100:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_phosphorus_wdir/depth_axis.nc for grid_weight
# 2021-03-22 09:04:25,592:76100:solver_state.py:__init__:"Newton" iteration now 0
# 2021-03-22 09:04:52,222:76100:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:04:52,223:76100:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# 2021-03-22 09:04:52,224:76100:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=8.222589e-16
# 2021-03-22 09:04:52,225:76100:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# 2021-03-22 09:04:52,228:76100:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-22 09:04:52,253:76100:tracer_module_state_base.py:log_vals:beta[phosphorus]=1.631757e-01
# 2021-03-22 09:05:15,861:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.549019e-01
# 2021-03-22 09:05:15,869:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.152653e-02
# 2021-03-22 09:05:15,872:76100:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-22 09:05:40,848:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.564621e-01
# 2021-03-22 09:05:40,850:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-9.100911e-03
# 2021-03-22 09:05:40,864:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.268014e-03
# 2021-03-22 09:05:40,868:76100:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-22 09:05:40,870:76100:krylov_solver.py:solve:Krylov convergence criterion satisfied
# 2021-03-22 09:05:40,877:76100:tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=-5.778672e-13
# 2021-03-22 09:05:40,879:76100:tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.567266e-01
# 2021-03-22 09:06:10,803:76100:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-22 09:06:10,805:76100:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-22 09:06:10,806:76100:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# 2021-03-22 09:06:10,808:76100:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=4.408268e-04
# 2021-03-22 09:06:10,810:76100:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-22 09:06:38,473:76100:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:06:38,474:76100:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.788519e+00
# 2021-03-22 09:06:38,476:76100:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=-9.070334e-16
# 2021-03-22 09:06:38,477:76100:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=4.131187e-04
# 2021-03-22 09:06:38,482:76100:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-03-22 09:07:04,348:76100:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:07:04,350:76100:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.788445e+00
# 2021-03-22 09:07:04,352:76100:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=2.108362e-15
# 2021-03-22 09:07:04,353:76100:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=1.748883e-04
# 2021-03-22 09:07:04,364:76100:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:07:04,365:76100:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.788445e+00
# 2021-03-22 09:07:04,367:76100:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=2.108362e-15
# 2021-03-22 09:07:04,369:76100:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=1.748883e-04
# 2021-03-22 09:07:04,371:76100:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-22 09:07:04,396:76100:tracer_module_state_base.py:log_vals:beta[phosphorus]=8.561509e-04
# 2021-03-22 09:07:30,700:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=7.698234e-04
# 2021-03-22 09:07:30,709:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=8.484018e-05
# 2021-03-22 09:07:30,713:76100:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-22 09:07:56,104:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=7.820928e-04
# 2021-03-22 09:07:56,106:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-7.148088e-05
# 2021-03-22 09:07:56,119:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.333838e-05
# 2021-03-22 09:07:56,123:76100:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-22 09:08:20,782:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=7.821355e-04
# 2021-03-22 09:08:20,783:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-7.335086e-05
# 2021-03-22 09:08:20,784:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.029852e-05
# 2021-03-22 09:08:20,798:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.141005e-06
# 2021-03-22 09:08:20,801:76100:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-22 09:08:20,803:76100:krylov_solver.py:solve:Krylov convergence criterion satisfied
# 2021-03-22 09:08:20,810:76100:tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=-2.236912e-15
# 2021-03-22 09:08:20,811:76100:tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=7.856350e-04
# 2021-03-22 09:08:44,624:76100:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-22 09:08:44,625:76100:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-22 09:08:44,627:76100:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.748883e-04
# 2021-03-22 09:08:44,628:76100:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=7.613018e-07
# 2021-03-22 09:08:44,629:76100:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-22 09:09:06,716:76100:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:09:06,718:76100:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-22 09:09:06,719:76100:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=2.043650e-15
# 2021-03-22 09:09:06,720:76100:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=7.560819e-07
# 2021-03-22 09:09:06,725:76100:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-03-22 09:09:28,943:76100:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:09:28,944:76100:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-22 09:09:28,946:76100:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=1.481462e-15
# 2021-03-22 09:09:28,947:76100:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=8.834671e-08
# 2021-03-22 09:09:28,958:76100:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:09:28,959:76100:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-22 09:09:28,961:76100:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=1.481462e-15
# 2021-03-22 09:09:28,962:76100:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=8.834671e-08
# 2021-03-22 09:09:28,964:76100:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-22 09:09:28,987:76100:tracer_module_state_base.py:log_vals:beta[phosphorus]=6.603329e-07
# 2021-03-22 09:09:50,127:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=6.350627e-07
# 2021-03-22 09:09:50,136:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=8.109953e-08
# 2021-03-22 09:09:50,139:76100:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-22 09:10:15,388:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=6.460186e-07
# 2021-03-22 09:10:15,390:76100:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-5.892873e-08
# 2021-03-22 09:10:15,403:76100:tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=6.349123e-09
# 2021-03-22 09:10:15,408:76100:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-22 09:10:15,410:76100:krylov_solver.py:solve:Krylov convergence criterion satisfied
# 2021-03-22 09:10:15,419:76100:tracer_module_state_base.py:log_vals:Newton increment 02,mean[phosphorus]=2.515815e-15
# 2021-03-22 09:10:15,421:76100:tracer_module_state_base.py:log_vals:Newton increment 02,norm[phosphorus]=6.487007e-07
# 2021-03-22 09:10:45,515:76100:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-22 09:10:45,517:76100:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-03-22 09:10:45,518:76100:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=8.834671e-08
# 2021-03-22 09:10:45,520:76100:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=3.059341e-09
# 2021-03-22 09:10:45,522:76100:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-22 09:11:14,018:76100:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:11:14,020:76100:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-22 09:11:14,022:76100:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,mean[phosphorus]=-6.375688e-16
# 2021-03-22 09:11:14,024:76100:tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,norm[phosphorus]=3.067006e-09
# 2021-03-22 09:11:14,042:76100:solver_state.py:inc_iteration:"Newton" iteration now 3
# 2021-03-22 09:11:40,357:76100:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:11:40,359:76100:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-22 09:11:40,360:76100:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,mean[phosphorus]=-1.722780e-15
# 2021-03-22 09:11:40,361:76100:tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,norm[phosphorus]=8.903898e-10
# 2021-03-22 09:11:40,372:76100:nk_driver.py:main:Newton convergence criterion satisfied
# 2021-03-22 09:11:40,374:76100:tracer_module_state_base.py:log_vals:iteration=03,iterate,mean[phosphorus]=5.962967e+00
# 2021-03-22 09:11:40,375:76100:tracer_module_state_base.py:log_vals:iteration=03,iterate,norm[phosphorus]=4.788295e+00
# 2021-03-22 09:11:40,377:76100:tracer_module_state_base.py:log_vals:iteration=03,fcn,mean[phosphorus]=-1.722780e-15
# 2021-03-22 09:11:40,378:76100:tracer_module_state_base.py:log_vals:iteration=03,fcn,norm[phosphorus]=8.903898e-10

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                      (depth: 30, depth_edges: 31, iteration: 4, nbnds: 2, region: 1)
# Coordinates:
#   * iteration                    (iteration) int32 0 1 2 3
#   * depth                        (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
#   * depth_edges                  (depth_edges) float64 0.0 10.0 ... 850.0 900.0
# Dimensions without coordinates: nbnds, region
# Data variables: (12/18)
#     iterate_mean_phosphorus      (iteration, region) float64 ...
#     iterate_norm_phosphorus      (iteration, region) float64 ...
#     fcn_mean_phosphorus          (iteration, region) float64 ...
#     fcn_norm_phosphorus          (iteration, region) float64 ...
#     increment_mean_phosphorus    (iteration, region) float64 ...
#     increment_norm_phosphorus    (iteration, region) float64 ...
#     ...                           ...
#     dop                          (iteration, region, depth) float64 ...
#     pop                          (iteration, region, depth) float64 ...
#     po4_s                        (iteration, region, depth) float64 ...
#     dop_s                        (iteration, region, depth) float64 ...
#     pop_s                        (iteration, region, depth) float64 ...
#     po4_uptake                   (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-03-22 09:04:25: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 03

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
