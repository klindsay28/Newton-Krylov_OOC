# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from src.test_problem import setup_solver
from src import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "phosphorus"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-02-22 10:15:05,393:3754:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg"
# 2021-02-22 10:15:05,399:3754:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_phosphorus_wdir/nk_driver.sh
# 2021-02-22 10:15:05,401:3754:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_phosphorus_wdir/depth_axis.nc"
# 2021-02-22 10:15:05,431:3754:setup_solver.py:main:fp_iter=0
# 2021-02-22 10:15:23,766:3754:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_phosphorus_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-02-22 10:15:05: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     po4_time_anom                   (time, depth) float64 ...
#     po4_time_std                    (depth) float64 ...
#     po4_time_delta                  (depth) float64 ...
#     po4_depth_int                   (time) float64 ...
#     dop                             (time, depth) float64 ...
#     dop_time_mean                   (depth) float64 ...
#     dop_time_anom                   (time, depth) float64 ...
#     dop_time_std                    (depth) float64 ...
#     dop_time_delta                  (depth) float64 ...
#     dop_depth_int                   (time) float64 ...
#     pop                             (time, depth) float64 ...
#     pop_time_mean                   (depth) float64 ...
#     pop_time_anom                   (time, depth) float64 ...
#     pop_time_std                    (depth) float64 ...
#     pop_time_delta                  (depth) float64 ...
#     pop_depth_int                   (time) float64 ...
#     po4_s                           (time, depth) float64 ...
#     po4_s_time_mean                 (depth) float64 ...
#     po4_s_time_anom                 (time, depth) float64 ...
#     po4_s_time_std                  (depth) float64 ...
#     po4_s_time_delta                (depth) float64 ...
#     po4_s_depth_int                 (time) float64 ...
#     dop_s                           (time, depth) float64 ...
#     dop_s_time_mean                 (depth) float64 ...
#     dop_s_time_anom                 (time, depth) float64 ...
#     dop_s_time_std                  (depth) float64 ...
#     dop_s_time_delta                (depth) float64 ...
#     dop_s_depth_int                 (time) float64 ...
#     pop_s                           (time, depth) float64 ...
#     pop_s_time_mean                 (depth) float64 ...
#     pop_s_time_anom                 (time, depth) float64 ...
#     pop_s_time_std                  (depth) float64 ...
#     pop_s_time_delta                (depth) float64 ...
#     pop_s_depth_int                 (time) float64 ...
#     po4_uptake                      (time, depth) float64 ...
#     po4_uptake_time_mean            (depth) float64 ...
#     po4_uptake_time_anom            (time, depth) float64 ...
#     po4_uptake_time_std             (depth) float64 ...
#     po4_uptake_time_delta           (depth) float64 ...
#     po4_uptake_depth_int            (time) float64 ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-02-22 10:15:05: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...
# Attributes:
#     history:  2021-02-22 10:15:23: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# 2021-02-22 10:15:33,103:3754:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-02-22 10:15:33,105:3754:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-02-22 10:15:33,124:3754:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-02-22 10:15:33,126:3754:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-02-22 10:15:33,128:3754:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-02-22 10:15:33,132:3754:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_phosphorus_wdir/depth_axis.nc for grid_weight
# 2021-02-22 10:15:33,139:3754:solver_state.py:__init__:"Newton" iteration now 0
# 2021-02-22 10:15:54,796:3754:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:15:54,798:3754:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# 2021-02-22 10:15:54,800:3754:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=-6.786563e-16
# 2021-02-22 10:15:54,801:3754:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# 2021-02-22 10:15:54,803:3754:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-02-22 10:16:14,652:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.559558e-01
# 2021-02-22 10:16:14,659:3754:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-02-22 10:16:35,816:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.565755e-01
# 2021-02-22 10:16:35,818:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-6.832152e-03
# 2021-02-22 10:16:35,826:3754:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-02-22 10:16:57,452:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.565814e-01
# 2021-02-22 10:16:57,453:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-6.913304e-03
# 2021-02-22 10:16:57,455:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=6.036381e-04
# 2021-02-22 10:16:57,472:3754:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-02-22 10:17:17,716:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.565882e-01
# 2021-02-22 10:17:17,717:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-6.919512e-03
# 2021-02-22 10:17:17,719:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=6.288665e-04
# 2021-02-22 10:17:17,720:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-8.490998e-05
# 2021-02-22 10:17:17,736:3754:tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=3.091620e-12
# 2021-02-22 10:17:17,737:3754:tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.567423e-01
# 2021-02-22 10:17:39,722:3754:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-02-22 10:17:39,723:3754:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-02-22 10:17:39,724:3754:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# 2021-02-22 10:17:39,725:3754:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=6.715137e-06
# 2021-02-22 10:17:39,726:3754:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-02-22 10:18:01,036:3754:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:18:01,038:3754:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.788397e+00
# 2021-02-22 10:18:01,039:3754:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=2.238452e-15
# 2021-02-22 10:18:01,041:3754:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=1.038974e-04
# 2021-02-22 10:18:01,049:3754:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-02-22 10:18:22,923:3754:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:18:22,924:3754:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.788392e+00
# 2021-02-22 10:18:22,926:3754:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=6.414163e-16
# 2021-02-22 10:18:22,927:3754:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=2.105067e-05
# 2021-02-22 10:18:22,937:3754:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:18:22,938:3754:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.788392e+00
# 2021-02-22 10:18:22,939:3754:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=6.414163e-16
# 2021-02-22 10:18:22,941:3754:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=2.105067e-05
# 2021-02-22 10:18:22,942:3754:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-02-22 10:18:42,652:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.443313e-04
# 2021-02-22 10:18:42,657:3754:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-02-22 10:19:02,428:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.503676e-04
# 2021-02-22 10:19:02,429:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-2.301690e-05
# 2021-02-22 10:19:02,437:3754:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-02-22 10:19:22,463:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.506108e-04
# 2021-02-22 10:19:22,464:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-2.329611e-05
# 2021-02-22 10:19:22,466:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.289625e-06
# 2021-02-22 10:19:22,475:3754:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-02-22 10:19:42,188:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.505926e-04
# 2021-02-22 10:19:42,190:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-2.327714e-05
# 2021-02-22 10:19:42,191:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=2.313186e-06
# 2021-02-22 10:19:42,193:3754:tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,3]=-1.491149e-07
# 2021-02-22 10:19:42,213:3754:tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=5.488994e-16
# 2021-02-22 10:19:42,215:3754:tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=1.523986e-04
# 2021-02-22 10:20:04,409:3754:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-02-22 10:20:04,411:3754:tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# 2021-02-22 10:20:04,412:3754:tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=2.105067e-05
# 2021-02-22 10:20:04,413:3754:tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=1.545274e-08
# 2021-02-22 10:20:04,415:3754:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-02-22 10:20:26,296:3754:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:20:26,297:3754:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.788295e+00
# 2021-02-22 10:20:26,298:3754:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=2.518665e-15
# 2021-02-22 10:20:26,299:3754:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=1.523198e-08
# 2021-02-22 10:20:26,304:3754:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-02-22 10:20:49,445:3754:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:20:49,446:3754:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.788295e+00
# 2021-02-22 10:20:49,447:3754:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=7.121953e-16
# 2021-02-22 10:20:49,449:3754:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=2.045347e-09
# 2021-02-22 10:20:49,460:3754:nk_driver.py:main:convergence criterion satisfied
# 2021-02-22 10:20:49,462:3754:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# 2021-02-22 10:20:49,463:3754:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.788295e+00
# 2021-02-22 10:20:49,465:3754:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=7.121953e-16
# 2021-02-22 10:20:49,467:3754:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=2.045347e-09

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                    (depth: 30, iteration: 3, region: 1)
# Coordinates:
#   * iteration                  (iteration) int32 0 1 2
#   * depth                      (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
# Dimensions without coordinates: region
# Data variables:
#     iterate_mean_phosphorus    (iteration, region) float64 ...
#     iterate_norm_phosphorus    (iteration, region) float64 ...
#     fcn_mean_phosphorus        (iteration, region) float64 ...
#     fcn_norm_phosphorus        (iteration, region) float64 ...
#     increment_mean_phosphorus  (iteration, region) float64 ...
#     increment_norm_phosphorus  (iteration, region) float64 ...
#     Armijo_factor_phosphorus   (iteration, region) float64 ...
#     po4                        (iteration, region, depth) float64 ...
#     dop                        (iteration, region, depth) float64 ...
#     pop                        (iteration, region, depth) float64 ...
#     po4_s                      (iteration, region, depth) float64 ...
#     dop_s                      (iteration, region, depth) float64 ...
#     pop_s                      (iteration, region, depth) float64 ...
#     po4_uptake                 (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-02-22 10:15:33: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 02

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
