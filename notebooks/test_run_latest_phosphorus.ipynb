# %%
import os
from shutil import rmtree
import sys

import xarray as xr

sys.path.append('..')

from nk_ooc.test_problem import setup_solver
from nk_ooc import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_phosphorus_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--logging_reproducible", "--tracer_module_names", "phosphorus"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# setup_solver.py:main:args.cfg_fnames="$repo_root/input/test_problem/newton_krylov.cfg,$repo_root/input/test_problem/model_params.cfg"
# gen_invoker_script.py:gen_invoker_script:generating $workdir/nk_driver.sh
# setup_solver.py:main:grid_weight_fname="$workdir/depth_axis.nc"
# setup_solver.py:main:fp_iter=0
# setup_solver.py:main:init_iterate_fname="$workdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, nbnds: 2, depth_edges: 31)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 101, depth: 30, nbnds: 2,
#                                      depth_edges: 31)
# Coordinates:
#   * time                            (time) object 0001-01-01 00:00:00 ... 000...
#   * depth                           (depth) float64 5.0 15.01 ... 825.0 875.0
#   * depth_edges                     (depth_edges) float64 0.0 10.0 ... 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/52)
#     depth_bounds                    (depth, nbnds) float64 ...
#     depth_delta                     (depth) float64 ...
#     bldepth                         (time) float64 ...
#     mixing_coeff                    (time, depth_edges) float64 ...
#     po4                             (time, depth) float64 ...
#     po4_time_mean                   (depth) float64 ...
#     ...                              ...
#     po4_s_restore_tau_r             (time, depth) float64 ...
#     po4_s_restore_tau_r_time_mean   (depth) float64 ...
#     po4_s_restore_tau_r_time_anom   (time, depth) float64 ...
#     po4_s_restore_tau_r_time_std    (depth) float64 ...
#     po4_s_restore_tau_r_time_delta  (depth) float64 ...
#     po4_s_restore_tau_r_depth_int   (time) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, nbnds: 2, depth_edges: 31)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     po4           (depth) float64 ...
#     dop           (depth) float64 ...
#     pop           (depth) float64 ...
#     po4_s         (depth) float64 ...
#     dop_s         (depth) float64 ...
#     pop_s         (depth) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
try:
    nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
except RuntimeError as err:
    print(str(err))
    print("number of maximum Newton iterations exceeded" not in str(err))
    if "number of maximum Newton iterations exceeded" not in str(err):
        raise
# Out:
# model_state_base.py:get_model_state_class:using class ModelState from nk_ooc.test_problem.model_state for model state
# model_config.py:__init__:loading content from $repo_root/input/test_problem/tracer_module_defs.yaml
# model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# model_config.py:__init__:reading depth_delta from $workdir/depth_axis.nc for grid_weight
# solver_state.py:__init__:"Newton" iteration now 0
# tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[phosphorus]=4.765667e+00
# tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[phosphorus]=-1.350862e-15
# tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[phosphorus]=1.848375e-02
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=1.631757e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=1.549019e-01
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.152652e-02
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=1.564621e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-9.100905e-03
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.268015e-03
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 00,mean[phosphorus]=3.440121e-13
# tracer_module_state_base.py:log_vals:Newton increment 00,norm[phosphorus]=1.567266e-01
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.848375e-02
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=4.408263e-04
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[phosphorus]=4.788519e+00
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[phosphorus]=-1.590819e-15
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[phosphorus]=4.131182e-04
# solver_state.py:inc_iteration:"Newton" iteration now 1
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[phosphorus]=4.788445e+00
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[phosphorus]=2.993340e-15
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[phosphorus]=1.748884e-04
# tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[phosphorus]=4.788445e+00
# tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[phosphorus]=2.993340e-15
# tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[phosphorus]=1.748884e-04
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=8.561478e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=7.698203e-04
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=8.484040e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=7.820896e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-7.148110e-05
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.333846e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=7.821323e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-7.335109e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,2]=1.029857e-05
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=1.141008e-06
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 01,mean[phosphorus]=7.803111e-15
# tracer_module_state_base.py:log_vals:Newton increment 01,norm[phosphorus]=7.856319e-04
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=1.748884e-04
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=7.612974e-07
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[phosphorus]=4.788295e+00
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[phosphorus]=5.163691e-15
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[phosphorus]=7.560774e-07
# solver_state.py:inc_iteration:"Newton" iteration now 2
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[phosphorus]=4.788295e+00
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[phosphorus]=5.286179e-16
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[phosphorus]=8.832765e-08
# tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[phosphorus]=4.788295e+00
# tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[phosphorus]=5.286179e-16
# tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[phosphorus]=8.832765e-08
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[phosphorus]=6.603537e-07
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus]=6.351107e-07
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=8.107249e-08
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,0]=6.460541e-07
# tracer_module_state_base.py:log_vals:KrylovCoeff[phosphorus,1]=-5.890732e-08
# tracer_module_state_base.py:log_vals:precond_resid[phosphorus]=6.350251e-09
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 02,mean[phosphorus]=9.029230e-16
# tracer_module_state_base.py:log_vals:Newton increment 02,norm[phosphorus]=6.487341e-07
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[phosphorus]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[phosphorus]=8.832765e-08
# tracer_module_state_base.py:log_vals:prov_fcn_norm[phosphorus]=3.040085e-09
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,norm[phosphorus]=4.788295e+00
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,mean[phosphorus]=-1.301542e-15
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,norm[phosphorus]=3.039021e-09
# solver_state.py:inc_iteration:"Newton" iteration now 3
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,norm[phosphorus]=4.788295e+00
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,mean[phosphorus]=1.632870e-15
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,norm[phosphorus]=8.873136e-10
# nk_driver.py:main:Newton convergence criterion satisfied
# tracer_module_state_base.py:log_vals:iteration=03,iterate,mean[phosphorus]=5.962967e+00
# tracer_module_state_base.py:log_vals:iteration=03,iterate,norm[phosphorus]=4.788295e+00
# tracer_module_state_base.py:log_vals:iteration=03,fcn,mean[phosphorus]=1.632870e-15
# tracer_module_state_base.py:log_vals:iteration=03,fcn,norm[phosphorus]=8.873136e-10

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                      (iteration: 4, region: 1, depth: 30, nbnds: 2,
#                                   depth_edges: 31)
# Coordinates:
#   * iteration                    (iteration) int32 0 1 2 3
#   * region                       (region) int32 0
#   * depth                        (depth) float64 5.0 15.01 25.07 ... 825.0 875.0
#   * depth_edges                  (depth_edges) float64 0.0 10.0 ... 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables: (12/18)
#     iterate_mean_phosphorus      (iteration, region) float64 ...
#     iterate_norm_phosphorus      (iteration, region) float64 ...
#     fcn_mean_phosphorus          (iteration, region) float64 ...
#     fcn_norm_phosphorus          (iteration, region) float64 ...
#     increment_mean_phosphorus    (iteration, region) float64 ...
#     increment_norm_phosphorus    (iteration, region) float64 ...
#     ...                           ...
#     dop                          (iteration, region, depth) float64 ...
#     pop                          (iteration, region, depth) float64 ...
#     po4_s                        (iteration, region, depth) float64 ...
#     dop_s                        (iteration, region, depth) float64 ...
#     pop_s                        (iteration, region, depth) float64 ...
#     po4_uptake                   (iteration, region, depth) float64 ...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 03

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
