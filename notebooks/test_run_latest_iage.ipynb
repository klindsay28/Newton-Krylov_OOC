# %%
import os
from shutil import rmtree

import xarray as xr

from src.test_problem import setup_solver
from src import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_iage_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "iage"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-03-16 07:25:22,632:43850:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg"
# 2021-03-16 07:25:22,640:43850:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_iage_wdir/nk_driver.sh
# 2021-03-16 07:25:22,643:43850:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_iage_wdir/depth_axis.nc"
# 2021-03-16 07:25:22,669:43850:setup_solver.py:main:fp_iter=0
# 2021-03-16 07:25:25,031:43850:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_iage_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     iage          (depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:22: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:          (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time             (time) object 0001-01-01 00:00:00 ... 0002-01-01 00:00:00
#   * depth            (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges      (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds     (depth, nbnds) float64 ...
#     depth_delta      (depth) float64 ...
#     bldepth          (time) float64 ...
#     mixing_coeff     (time, depth_edges) float64 ...
#     iage             (time, depth) float64 ...
#     iage_time_mean   (depth) float64 ...
#     iage_time_anom   (time, depth) float64 ...
#     iage_time_std    (depth) float64 ...
#     iage_time_delta  (depth) float64 ...
#     iage_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:22: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     iage          (depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:25: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
# Out:
# 2021-03-16 07:25:26,481:43850:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-03-16 07:25:26,482:43850:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-03-16 07:25:26,498:43850:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-03-16 07:25:26,499:43850:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-03-16 07:25:26,500:43850:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-03-16 07:25:26,511:43850:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_iage_wdir/depth_axis.nc for grid_weight
# 2021-03-16 07:25:26,513:43850:solver_state.py:__init__:"Newton" iteration now 0
# 2021-03-16 07:25:28,933:43850:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[iage]=5.675355e+02
# 2021-03-16 07:25:28,934:43850:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[iage]=6.866744e+02
# 2021-03-16 07:25:28,935:43850:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[iage]=-6.279780e-01
# 2021-03-16 07:25:28,936:43850:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[iage]=2.680751e+00
# 2021-03-16 07:25:28,937:43850:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:25:31,366:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=1.111386e+02
# 2021-03-16 07:25:31,370:43850:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:25:33,733:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143861e+02
# 2021-03-16 07:25:33,733:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.880879e+00
# 2021-03-16 07:25:33,738:43850:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:25:36,204:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143443e+02
# 2021-03-16 07:25:36,205:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.912124e+00
# 2021-03-16 07:25:36,205:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=2.025858e-01
# 2021-03-16 07:25:36,212:43850:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:25:38,591:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143527e+02
# 2021-03-16 07:25:38,592:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.908016e+00
# 2021-03-16 07:25:38,593:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=2.048809e-01
# 2021-03-16 07:25:38,594:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,3]=-1.342292e-02
# 2021-03-16 07:25:38,602:43850:tracer_module_state_base.py:log_vals:Newton increment 00,mean[iage]=-9.108381e+01
# 2021-03-16 07:25:38,603:43850:tracer_module_state_base.py:log_vals:Newton increment 00,norm[iage]=1.144581e+02
# 2021-03-16 07:25:41,422:43850:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:25:41,423:43850:tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# 2021-03-16 07:25:41,424:43850:tracer_module_state_base.py:log_vals:fcn_norm[iage]=2.680751e+00
# 2021-03-16 07:25:41,426:43850:tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=6.874727e-04
# 2021-03-16 07:25:41,427:43850:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:25:41,433:43850:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[iage]=4.764517e+02
# 2021-03-16 07:25:41,435:43850:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[iage]=5.750831e+02
# 2021-03-16 07:25:41,436:43850:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[iage]=-7.107279e-05
# 2021-03-16 07:25:41,437:43850:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[iage]=6.874727e-04
# 2021-03-16 07:25:41,441:43850:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-03-16 07:25:44,500:43850:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[iage]=4.764516e+02
# 2021-03-16 07:25:44,501:43850:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[iage]=5.750831e+02
# 2021-03-16 07:25:44,503:43850:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[iage]=1.785305e-05
# 2021-03-16 07:25:44,504:43850:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[iage]=1.893308e-04
# 2021-03-16 07:25:44,511:43850:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[iage]=4.764516e+02
# 2021-03-16 07:25:44,512:43850:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[iage]=5.750831e+02
# 2021-03-16 07:25:44,514:43850:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[iage]=1.785305e-05
# 2021-03-16 07:25:44,515:43850:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[iage]=1.893308e-04
# 2021-03-16 07:25:44,517:43850:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-16 07:25:47,585:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=5.352450e-04
# 2021-03-16 07:25:47,589:43850:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-16 07:25:50,343:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=6.432016e-04
# 2021-03-16 07:25:50,344:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-2.924040e-04
# 2021-03-16 07:25:50,349:43850:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-16 07:25:53,148:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=6.429306e-04
# 2021-03-16 07:25:53,150:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-2.952955e-04
# 2021-03-16 07:25:53,151:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=8.644086e-06
# 2021-03-16 07:25:53,157:43850:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-16 07:25:56,100:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=6.430435e-04
# 2021-03-16 07:25:56,102:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-2.949961e-04
# 2021-03-16 07:25:56,103:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=8.764782e-06
# 2021-03-16 07:25:56,105:43850:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,3]=-6.103002e-07
# 2021-03-16 07:25:56,117:43850:tracer_module_state_base.py:log_vals:Newton increment 01,mean[iage]=-3.377953e-05
# 2021-03-16 07:25:56,119:43850:tracer_module_state_base.py:log_vals:Newton increment 01,norm[iage]=7.075343e-04
# 2021-03-16 07:25:59,364:43850:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-16 07:25:59,365:43850:tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# 2021-03-16 07:25:59,366:43850:tracer_module_state_base.py:log_vals:fcn_norm[iage]=1.893308e-04
# 2021-03-16 07:25:59,368:43850:tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=2.903811e-08
# 2021-03-16 07:25:59,369:43850:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-16 07:25:59,377:43850:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[iage]=4.764516e+02
# 2021-03-16 07:25:59,379:43850:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[iage]=5.750830e+02
# 2021-03-16 07:25:59,380:43850:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[iage]=3.880630e-09
# 2021-03-16 07:25:59,381:43850:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[iage]=2.903811e-08
# 2021-03-16 07:25:59,387:43850:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-03-16 07:26:02,336:43850:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[iage]=4.764516e+02
# 2021-03-16 07:26:02,338:43850:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[iage]=5.750830e+02
# 2021-03-16 07:26:02,339:43850:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[iage]=-2.860222e-10
# 2021-03-16 07:26:02,341:43850:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[iage]=5.263913e-09
# 2021-03-16 07:26:02,348:43850:nk_driver.py:main:convergence criterion satisfied
# 2021-03-16 07:26:02,349:43850:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[iage]=4.764516e+02
# 2021-03-16 07:26:02,350:43850:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[iage]=5.750830e+02
# 2021-03-16 07:26:02,352:43850:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[iage]=-2.860222e-10
# 2021-03-16 07:26:02,352:43850:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[iage]=5.263913e-09

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:              (depth: 30, depth_edges: 31, iteration: 3, nbnds: 2, region: 1)
# Coordinates:
#   * iteration            (iteration) int32 0 1 2
#   * depth                (depth) float64 5.0 15.01 25.07 ... 775.1 825.0 875.0
#   * depth_edges          (depth_edges) float64 0.0 10.0 20.02 ... 850.0 900.0
# Dimensions without coordinates: nbnds, region
# Data variables:
#     iterate_mean_iage    (iteration, region) float64 ...
#     iterate_norm_iage    (iteration, region) float64 ...
#     fcn_mean_iage        (iteration, region) float64 ...
#     fcn_norm_iage        (iteration, region) float64 ...
#     increment_mean_iage  (iteration, region) float64 ...
#     increment_norm_iage  (iteration, region) float64 ...
#     Armijo_factor_iage   (iteration, region) float64 ...
#     depth_bounds         (depth, nbnds) float64 ...
#     depth_delta          (depth) float64 ...
#     iage                 (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-03-16 07:25:26: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 02

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
