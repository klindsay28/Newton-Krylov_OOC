# %%
import os
from shutil import rmtree

import xarray as xr

from src.test_problem import setup_solver
from src import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_iage_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--tracer_module_names", "iage"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# 2021-03-15 11:46:46,344:28598:setup_solver.py:main:args.cfg_fnames="/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/newton_krylov.cfg,/Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/model_params.cfg"
# 2021-03-15 11:46:46,352:28598:gen_invoker_script.py:gen_invoker_script:generating /Users/klindsay/test_run_latest_iage_wdir/nk_driver.sh
# 2021-03-15 11:46:46,354:28598:setup_solver.py:main:grid_weight_fname="/Users/klindsay/test_run_latest_iage_wdir/depth_axis.nc"
# 2021-03-15 11:46:46,379:28598:setup_solver.py:main:fp_iter=0
# 2021-03-15 11:46:48,857:28598:setup_solver.py:main:init_iterate_fname="/Users/klindsay/test_run_latest_iage_wdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     iage          (depth) float64 ...
# Attributes:
#     history:  2021-03-15 11:46:46: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:          (depth: 30, depth_edges: 31, nbnds: 2, time: 101)
# Coordinates:
#   * time             (time) object 0001-01-01 00:00:00 ... 0002-01-01 00:00:00
#   * depth            (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges      (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds     (depth, nbnds) float64 ...
#     depth_delta      (depth) float64 ...
#     bldepth          (time) float64 ...
#     mixing_coeff     (time, depth_edges) float64 ...
#     iage             (time, depth) float64 ...
#     iage_time_mean   (depth) float64 ...
#     iage_time_anom   (time, depth) float64 ...
#     iage_time_std    (depth) float64 ...
#     iage_time_delta  (depth) float64 ...
#     iage_depth_int   (time) float64 ...
# Attributes:
#     history:  2021-03-15 11:46:46: created by src.test_problem.model_state._g...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, depth_edges: 31, nbnds: 2)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     iage          (depth) float64 ...
# Attributes:
#     history:  2021-03-15 11:46:48: created by src.test_problem.model_state.Mo...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
# Out:
# 2021-03-15 11:46:50,285:28598:nk_driver.py:_get_model_state_class:using class ModelState from src.test_problem.model_state for model state
# 2021-03-15 11:46:50,286:28598:model_config.py:__init__:loading content from /Users/klindsay/codes/Newton-Krylov_OOC/input/test_problem/tracer_module_defs.yaml
# 2021-03-15 11:46:50,299:28598:model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# 2021-03-15 11:46:50,301:28598:model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# 2021-03-15 11:46:50,302:28598:model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# 2021-03-15 11:46:50,304:28598:model_config.py:__init__:reading depth_delta from /Users/klindsay/test_run_latest_iage_wdir/depth_axis.nc for grid_weight
# 2021-03-15 11:46:50,306:28598:solver_state.py:__init__:"Newton" iteration now 0
# 2021-03-15 11:46:52,664:28598:tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[iage]=5.675355e+02
# 2021-03-15 11:46:52,665:28598:tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[iage]=6.866744e+02
# 2021-03-15 11:46:52,666:28598:tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[iage]=-6.279780e-01
# 2021-03-15 11:46:52,668:28598:tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[iage]=2.680751e+00
# 2021-03-15 11:46:52,669:28598:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-15 11:46:54,944:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=1.111386e+02
# 2021-03-15 11:46:54,948:28598:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-15 11:46:57,379:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143861e+02
# 2021-03-15 11:46:57,380:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.880883e+00
# 2021-03-15 11:46:57,386:28598:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-15 11:46:59,673:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143443e+02
# 2021-03-15 11:46:59,673:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.912128e+00
# 2021-03-15 11:46:59,674:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=2.025859e-01
# 2021-03-15 11:46:59,681:28598:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-15 11:47:02,427:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143527e+02
# 2021-03-15 11:47:02,428:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.908020e+00
# 2021-03-15 11:47:02,430:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=2.048810e-01
# 2021-03-15 11:47:02,431:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,3]=-1.342293e-02
# 2021-03-15 11:47:02,441:28598:tracer_module_state_base.py:log_vals:Newton increment 00,mean[iage]=-9.108380e+01
# 2021-03-15 11:47:02,443:28598:tracer_module_state_base.py:log_vals:Newton increment 00,norm[iage]=1.144581e+02
# 2021-03-15 11:47:05,659:28598:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-15 11:47:05,661:28598:tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# 2021-03-15 11:47:05,663:28598:tracer_module_state_base.py:log_vals:fcn_norm[iage]=2.680751e+00
# 2021-03-15 11:47:05,664:28598:tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=6.875398e-04
# 2021-03-15 11:47:05,666:28598:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-15 11:47:05,674:28598:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[iage]=4.764517e+02
# 2021-03-15 11:47:05,676:28598:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[iage]=5.750831e+02
# 2021-03-15 11:47:05,677:28598:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[iage]=-7.128855e-05
# 2021-03-15 11:47:05,679:28598:tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[iage]=6.875398e-04
# 2021-03-15 11:47:05,684:28598:solver_state.py:inc_iteration:"Newton" iteration now 1
# 2021-03-15 11:47:09,065:28598:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[iage]=4.764517e+02
# 2021-03-15 11:47:09,067:28598:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[iage]=5.750831e+02
# 2021-03-15 11:47:09,068:28598:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[iage]=1.774755e-05
# 2021-03-15 11:47:09,070:28598:tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[iage]=1.891409e-04
# 2021-03-15 11:47:09,078:28598:tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[iage]=4.764517e+02
# 2021-03-15 11:47:09,080:28598:tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[iage]=5.750831e+02
# 2021-03-15 11:47:09,081:28598:tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[iage]=1.774755e-05
# 2021-03-15 11:47:09,083:28598:tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[iage]=1.891409e-04
# 2021-03-15 11:47:09,085:28598:solver_state.py:__init__:"Krylov" iteration now 0
# 2021-03-15 11:47:12,029:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=5.340216e-04
# 2021-03-15 11:47:12,034:28598:solver_state.py:inc_iteration:"Krylov" iteration now 1
# 2021-03-15 11:47:15,033:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=6.439224e-04
# 2021-03-15 11:47:15,035:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-2.927207e-04
# 2021-03-15 11:47:15,040:28598:solver_state.py:inc_iteration:"Krylov" iteration now 2
# 2021-03-15 11:47:18,145:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=6.436827e-04
# 2021-03-15 11:47:18,146:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-2.956168e-04
# 2021-03-15 11:47:18,147:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=8.640748e-06
# 2021-03-15 11:47:18,155:28598:solver_state.py:inc_iteration:"Krylov" iteration now 3
# 2021-03-15 11:47:21,179:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=6.437919e-04
# 2021-03-15 11:47:21,180:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-2.953160e-04
# 2021-03-15 11:47:21,182:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=8.761534e-06
# 2021-03-15 11:47:21,183:28598:tracer_module_state_base.py:log_vals:KrylovCoeff[iage,3]=-6.099356e-07
# 2021-03-15 11:47:21,193:28598:tracer_module_state_base.py:log_vals:Newton increment 01,mean[iage]=-4.152772e-05
# 2021-03-15 11:47:21,195:28598:tracer_module_state_base.py:log_vals:Newton increment 01,norm[iage]=7.083478e-04
# 2021-03-15 11:47:24,703:28598:newton_solver.py:_comp_next_iterate:Armijo_ind=0
# 2021-03-15 11:47:24,704:28598:tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# 2021-03-15 11:47:24,706:28598:tracer_module_state_base.py:log_vals:fcn_norm[iage]=1.891409e-04
# 2021-03-15 11:47:24,707:28598:tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=2.881405e-08
# 2021-03-15 11:47:24,709:28598:newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# 2021-03-15 11:47:24,719:28598:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[iage]=4.764516e+02
# 2021-03-15 11:47:24,721:28598:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[iage]=5.750830e+02
# 2021-03-15 11:47:24,722:28598:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[iage]=3.813089e-09
# 2021-03-15 11:47:24,724:28598:tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[iage]=2.881405e-08
# 2021-03-15 11:47:24,730:28598:solver_state.py:inc_iteration:"Newton" iteration now 2
# 2021-03-15 11:47:28,061:28598:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[iage]=4.764516e+02
# 2021-03-15 11:47:28,063:28598:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[iage]=5.750830e+02
# 2021-03-15 11:47:28,064:28598:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[iage]=-2.445437e-10
# 2021-03-15 11:47:28,066:28598:tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[iage]=5.248438e-09
# 2021-03-15 11:47:28,073:28598:nk_driver.py:main:convergence criterion satisfied
# 2021-03-15 11:47:28,075:28598:tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[iage]=4.764516e+02
# 2021-03-15 11:47:28,076:28598:tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[iage]=5.750830e+02
# 2021-03-15 11:47:28,078:28598:tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[iage]=-2.445437e-10
# 2021-03-15 11:47:28,079:28598:tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[iage]=5.248438e-09

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:              (depth: 30, depth_edges: 31, iteration: 3, nbnds: 2, region: 1)
# Coordinates:
#   * iteration            (iteration) int32 0 1 2
#   * depth                (depth) float64 5.0 15.01 25.07 ... 775.1 825.0 875.0
#   * depth_edges          (depth_edges) float64 0.0 10.0 20.02 ... 850.0 900.0
# Dimensions without coordinates: nbnds, region
# Data variables:
#     iterate_mean_iage    (iteration, region) float64 ...
#     iterate_norm_iage    (iteration, region) float64 ...
#     fcn_mean_iage        (iteration, region) float64 ...
#     fcn_norm_iage        (iteration, region) float64 ...
#     increment_mean_iage  (iteration, region) float64 ...
#     increment_norm_iage  (iteration, region) float64 ...
#     Armijo_factor_iage   (iteration, region) float64 ...
#     depth_bounds         (depth, nbnds) float64 ...
#     depth_delta          (depth) float64 ...
#     iage                 (iteration, region, depth) float64 ...
# Attributes:
#     history:  2021-03-15 11:46:50: created by src.stats_file.StatsFile._creat...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 02

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
