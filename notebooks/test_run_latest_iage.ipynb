# %%
import os
from shutil import rmtree

import xarray as xr

from nk_ooc.test_problem import setup_solver
from nk_ooc import nk_driver

from utils import plot_all_vars

# %matplotlib inline

# %%
wdir = os.path.join(os.getenv("HOME"), "test_run_latest_iage_wdir")
if os.path.exists(wdir):
    if os.path.isfile(wdir):
        os.remove(wdir)
    else:
        rmtree(wdir)

# %%
# args common to all invocations to parse_args
args_base = ["--workdir", wdir, "--logging_reproducible", "--tracer_module_names", "iage"]

# %%
setup_solver.main(setup_solver.parse_args(args_base + ["--fp_cnt", "1"]))
# Out:
# setup_solver.py:main:args.cfg_fnames="$repo_root/input/test_problem/newton_krylov.cfg,$repo_root/input/test_problem/model_params.cfg"
# gen_invoker_script.py:gen_invoker_script:generating $workdir/nk_driver.sh
# setup_solver.py:main:grid_weight_fname="$workdir/depth_axis.nc"
# setup_solver.py:main:fp_iter=0
# setup_solver.py:main:init_iterate_fname="$workdir/gen_init_iterate/init_iterate.nc"

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, nbnds: 2, depth_edges: 31)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     iage          (depth) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "hist_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 101, depth: 30, nbnds: 2, depth_edges: 31)
# Coordinates:
#   * time             (time) object 0001-01-01 00:00:00 ... 0002-01-01 00:00:00
#   * depth            (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges      (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds     (depth, nbnds) float64 ...
#     depth_delta      (depth) float64 ...
#     bldepth          (time) float64 ...
#     mixing_coeff     (time, depth_edges) float64 ...
#     iage             (time, depth) float64 ...
#     iage_time_mean   (depth) float64 ...
#     iage_time_anom   (time, depth) float64 ...
#     iage_time_std    (depth) float64 ...
#     iage_time_delta  (depth) float64 ...
#     iage_depth_int   (time) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "fcn_00.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 30, nbnds: 2, depth_edges: 31)
# Coordinates:
#   * depth         (depth) float64 5.0 15.01 25.07 35.32 ... 775.1 825.0 875.0
#   * depth_edges   (depth_edges) float64 0.0 10.0 20.02 ... 800.0 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     depth_bounds  (depth, nbnds) float64 ...
#     depth_delta   (depth) float64 ...
#     iage          (depth) float64 ...

# %%
with xr.open_dataset(os.path.join(wdir, "gen_init_iterate", "init_iterate.nc")) as ds:
    plot_all_vars(ds)

# %%
nk_driver.main(nk_driver.parse_args(args_base + ["--persist"]))
# Out:
# model_state_base.py:get_model_state_class:using class ModelState from nk_ooc.test_problem.model_state for model state
# model_config.py:__init__:loading content from $repo_root/input/test_problem/tracer_module_defs.yaml
# model_config.py:check_shadow_tracers:tracer module phosphorus has po4_s as a shadow for po4
# model_config.py:check_shadow_tracers:tracer module phosphorus has dop_s as a shadow for dop
# model_config.py:check_shadow_tracers:tracer module phosphorus has pop_s as a shadow for pop
# model_config.py:__init__:reading depth_delta from $workdir/depth_axis.nc for grid_weight
# solver_state.py:__init__:"Newton" iteration now 0
# tracer_module_state_base.py:log_vals:iteration=00,iterate,mean[iage]=5.675355e+02
# tracer_module_state_base.py:log_vals:iteration=00,iterate,norm[iage]=6.866744e+02
# tracer_module_state_base.py:log_vals:iteration=00,fcn,mean[iage]=-6.279780e-01
# tracer_module_state_base.py:log_vals:iteration=00,fcn,norm[iage]=2.680751e+00
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[iage]=1.245192e+02
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=1.111386e+02
# tracer_module_state_base.py:log_vals:precond_resid[iage]=6.466285e+00
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.143861e+02
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.880879e+00
# tracer_module_state_base.py:log_vals:precond_resid[iage]=2.254414e-01
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 00,mean[iage]=-9.112036e+01
# tracer_module_state_base.py:log_vals:Newton increment 00,norm[iage]=1.144902e+02
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[iage]=2.680751e+00
# tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=7.423627e-02
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,mean[iage]=4.764152e+02
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,iterate,norm[iage]=5.750816e+02
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,mean[iage]=5.052473e-03
# tracer_module_state_base.py:log_vals:iteration=00,pre-fp_iter,fcn,norm[iage]=7.423627e-02
# solver_state.py:inc_iteration:"Newton" iteration now 1
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,mean[iage]=4.764202e+02
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,iterate,norm[iage]=5.750817e+02
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,mean[iage]=9.572492e-04
# tracer_module_state_base.py:log_vals:iteration=01,fp_iter=01,fcn,norm[iage]=2.473401e-02
# tracer_module_state_base.py:log_vals:iteration=01,iterate,mean[iage]=4.764202e+02
# tracer_module_state_base.py:log_vals:iteration=01,iterate,norm[iage]=5.750817e+02
# tracer_module_state_base.py:log_vals:iteration=01,fcn,mean[iage]=9.572492e-04
# tracer_module_state_base.py:log_vals:iteration=01,fcn,norm[iage]=2.473401e-02
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[iage]=1.871625e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=1.717587e-01
# tracer_module_state_base.py:log_vals:precond_resid[iage]=1.643075e-02
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.718922e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-1.916807e-02
# tracer_module_state_base.py:log_vals:precond_resid[iage]=3.615417e-03
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=1.726277e-01
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-1.788085e-02
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=1.827933e-03
# tracer_module_state_base.py:log_vals:precond_resid[iage]=1.587259e-04
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 01,mean[iage]=3.143397e-02
# tracer_module_state_base.py:log_vals:Newton increment 01,norm[iage]=1.735609e-01
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[iage]=2.473401e-02
# tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=6.727227e-05
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,mean[iage]=4.764516e+02
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,iterate,norm[iage]=5.750831e+02
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,mean[iage]=-5.908468e-06
# tracer_module_state_base.py:log_vals:iteration=01,pre-fp_iter,fcn,norm[iage]=6.727227e-05
# solver_state.py:inc_iteration:"Newton" iteration now 2
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,mean[iage]=4.764516e+02
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,iterate,norm[iage]=5.750831e+02
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,mean[iage]=2.714155e-06
# tracer_module_state_base.py:log_vals:iteration=02,fp_iter=01,fcn,norm[iage]=2.202016e-05
# tracer_module_state_base.py:log_vals:iteration=02,iterate,mean[iage]=4.764516e+02
# tracer_module_state_base.py:log_vals:iteration=02,iterate,norm[iage]=5.750831e+02
# tracer_module_state_base.py:log_vals:iteration=02,fcn,mean[iage]=2.714155e-06
# tracer_module_state_base.py:log_vals:iteration=02,fcn,norm[iage]=2.202016e-05
# solver_state.py:__init__:"Krylov" iteration now 0
# tracer_module_state_base.py:log_vals:beta[iage]=1.139551e-04
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage]=7.564622e-05
# tracer_module_state_base.py:log_vals:precond_resid[iage]=5.317425e-05
# solver_state.py:inc_iteration:"Krylov" iteration now 1
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=9.876630e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.755175e-05
# tracer_module_state_base.py:log_vals:precond_resid[iage]=1.429248e-06
# solver_state.py:inc_iteration:"Krylov" iteration now 2
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,0]=9.873726e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,1]=-4.825701e-05
# tracer_module_state_base.py:log_vals:KrylovCoeff[iage,2]=1.228446e-06
# tracer_module_state_base.py:log_vals:precond_resid[iage]=1.161979e-07
# solver_state.py:inc_iteration:"Krylov" iteration now 3
# krylov_solver.py:solve:Krylov convergence criterion satisfied
# tracer_module_state_base.py:log_vals:Newton increment 02,mean[iage]=-2.799339e-05
# tracer_module_state_base.py:log_vals:Newton increment 02,norm[iage]=1.099058e-04
# newton_solver.py:_comp_next_iterate:Armijo_ind=0
# tracer_module_state_base.py:log_vals:ArmijoFactor[iage]=1.000000e+00
# tracer_module_state_base.py:log_vals:fcn_norm[iage]=2.202016e-05
# tracer_module_state_base.py:log_vals:prov_fcn_norm[iage]=4.484058e-08
# newton_solver.py:_comp_next_iterate:Armijo condition satisfied
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,mean[iage]=4.764516e+02
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,iterate,norm[iage]=5.750830e+02
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,mean[iage]=-3.095703e-09
# tracer_module_state_base.py:log_vals:iteration=02,pre-fp_iter,fcn,norm[iage]=4.484058e-08
# solver_state.py:inc_iteration:"Newton" iteration now 3
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,mean[iage]=4.764516e+02
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,iterate,norm[iage]=5.750830e+02
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,mean[iage]=8.591615e-10
# tracer_module_state_base.py:log_vals:iteration=03,fp_iter=01,fcn,norm[iage]=1.657208e-08
# nk_driver.py:main:Newton convergence criterion satisfied
# tracer_module_state_base.py:log_vals:iteration=03,iterate,mean[iage]=4.764516e+02
# tracer_module_state_base.py:log_vals:iteration=03,iterate,norm[iage]=5.750830e+02
# tracer_module_state_base.py:log_vals:iteration=03,fcn,mean[iage]=8.591615e-10
# tracer_module_state_base.py:log_vals:iteration=03,fcn,norm[iage]=1.657208e-08

# %%
with xr.open_dataset(os.path.join(wdir, "Newton_stats.nc")) as ds:
    del ds.attrs["history"]
    print(ds)
    plot_all_vars(ds)
    iterations = len(ds["iteration"])
# Out:
# <xarray.Dataset>
# Dimensions:                (iteration: 4, region: 1, depth: 30, nbnds: 2,
#                             depth_edges: 31)
# Coordinates:
#   * iteration              (iteration) int32 0 1 2 3
#   * region                 (region) int32 0
#   * depth                  (depth) float64 5.0 15.01 25.07 ... 775.1 825.0 875.0
#   * depth_edges            (depth_edges) float64 0.0 10.0 20.02 ... 850.0 900.0
# Dimensions without coordinates: nbnds
# Data variables:
#     iterate_mean_iage      (iteration, region) float64 ...
#     iterate_norm_iage      (iteration, region) float64 ...
#     fcn_mean_iage          (iteration, region) float64 ...
#     fcn_norm_iage          (iteration, region) float64 ...
#     increment_mean_iage    (iteration, region) float64 ...
#     increment_norm_iage    (iteration, region) float64 ...
#     increment_scalef_iage  (iteration) float64 ...
#     Armijo_factor_iage     (iteration, region) float64 ...
#     Krylov_iterations      (iteration) float64 ...
#     depth_bounds           (depth, nbnds) float64 ...
#     depth_delta            (depth) float64 ...
#     iage                   (iteration, region, depth) float64 ...

# %%
iter_str_final = f"{iterations-1:02d}"
print(iter_str_final)
# Out:
# 03

# %%
with xr.open_dataset(os.path.join(wdir, f"iterate_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"hist_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)

# %%
with xr.open_dataset(os.path.join(wdir, f"fcn_{iter_str_final}.nc")) as ds:
    plot_all_vars(ds)
